# %% [markdown]
# <a href="https://colab.research.google.com/github/PraphulKamabathula/DS1002-qtm3tc/blob/main/homework/week-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 7
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL for your notebook for review.
#
# Load the following dataset into pandas and perform the requested operations in code.
#
# Source: https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv

# %%
# Load pandas and the data
import numpy as np
import pandas as pd

# %%
ride_sharing = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv')

# %%
# show how many rows and columns are in this dataset
ride_sharing.shape
# Out:
# (25760, 10)

# %%
ride_sharing.head(15)
# Out:
#        duration  station_A_id  \
# 0    12 minutes            81
# 1    24 minutes             3
# 2     8 minutes            67
# 3     4 minutes            16
# 4    11 minutes            22
# 5    10 minutes            22
# 6    16 minutes            67
# 7     9 minutes            30
# 8    21 minutes            81
# 9     5 minutes            30
# 10   19 minutes            81
# 11    6 minutes             3
# 12    7 minutes             3
# 13  187 minutes            15
# 14   13 minutes            21
#
#                                        station_A_name  station_B_id  \
# 0                                  Berry St at 4th St           323
# 1        Powell St BART Station (Market St at 4th St)           118
# 2   San Francisco Caltrain Station 2  (Townsend St...            23
# 3                             Steuart St at Market St            28
# 4                               Howard St at Beale St           350
# 5                               Howard St at Beale St             6
# 6   San Francisco Caltrain Station 2  (Townsend St...           107
# 7      San Francisco Caltrain (Townsend St at 4th St)            97
# 8                                  Berry St at 4th St            16
# 9      San Francisco Caltrain (Townsend St at 4th St)            62
# 10                                 Berry St at 4th St            16
# 11       Powell St BART Station (Market St at 4th St)            26
# 12       Powell St BART Station (Market St at 4th St)            27
# 13  San Francisco Ferry Building (Harry Bridges Pl...           355
# 14   Montgomery St BART Station (Market St at 2nd St)            74
#
#                      station_B_name  bike_id  user_type  user_birth_year  \
# 0                Broadway at Kearny     5480          2             1959
# 1   Eureka Valley Recreation Center     5193          2             1965
# 2     The Embarcadero at Steuart St     3652          3             1993
# 3      The Embarcadero at Bryant St     1883          1             1979
# 4              8th St at Brannan St     4626          2             1994
# 5     The Embarcadero at Sansome St     3279          2             1979
# 6             17th St at Dolores St     1035          2             1981
# 7             14th St at Mission St     5286          2             1991
# 8           Steuart St at Market St     2124          1             1982
# 9       Victoria Manalo Draves Park      333          1             1994
# 10          Steuart St at Market St     1883          2             1983
# 11              1st St at Folsom St     5331          1             1990
# 12          Beale St at Harrison St     1863          3             1998
# 13          23rd St at Tennessee St      674          2             1987
# 14            Laguna St at Hayes St     5487          2             1997
#
#    user_gender  tire_size
# 0         Male         26
# 1         Male         27
# 2         Male         29
# 3         Male         26
# 4         Male         27
# 5         Male         29
# 6         Male         26
# 7         Male         27
# 8       Female         29
# 9         Male         26
# 10        Male         27
# 11        Male         29
# 12        Male         26
# 13      Female         27
# 14        Male         29

# %%
# The first column, "duration" is seen as a string.
# Using two snippets of code, clean this column up so that
# is now an integer (int64)
ride_sharing['duration'] = ride_sharing['duration'].str.strip('minutes')
ride_sharing['duration'] = ride_sharing['duration'].astype('int')

# %%
# Now display the datatypes in the updated dataframe
ride_sharing.head(15)
# Out:
#     duration  station_A_id                                     station_A_name  \
# 0         12            81                                 Berry St at 4th St
# 1         24             3       Powell St BART Station (Market St at 4th St)
# 2          8            67  San Francisco Caltrain Station 2  (Townsend St...
# 3          4            16                            Steuart St at Market St
# 4         11            22                              Howard St at Beale St
# 5         10            22                              Howard St at Beale St
# 6         16            67  San Francisco Caltrain Station 2  (Townsend St...
# 7          9            30     San Francisco Caltrain (Townsend St at 4th St)
# 8         21            81                                 Berry St at 4th St
# 9          5            30     San Francisco Caltrain (Townsend St at 4th St)
# 10        19            81                                 Berry St at 4th St
# 11         6             3       Powell St BART Station (Market St at 4th St)
# 12         7             3       Powell St BART Station (Market St at 4th St)
# 13       187            15  San Francisco Ferry Building (Harry Bridges Pl...
# 14        13            21   Montgomery St BART Station (Market St at 2nd St)
#
#     station_B_id                   station_B_name  bike_id  user_type  \
# 0            323               Broadway at Kearny     5480          2
# 1            118  Eureka Valley Recreation Center     5193          2
# 2             23    The Embarcadero at Steuart St     3652          3
# 3             28     The Embarcadero at Bryant St     1883          1
# 4            350             8th St at Brannan St     4626          2
# 5              6    The Embarcadero at Sansome St     3279          2
# 6            107            17th St at Dolores St     1035          2
# 7             97            14th St at Mission St     5286          2
# 8             16          Steuart St at Market St     2124          1
# 9             62      Victoria Manalo Draves Park      333          1
# 10            16          Steuart St at Market St     1883          2
# 11            26              1st St at Folsom St     5331          1
# 12            27          Beale St at Harrison St     1863          3
# 13           355          23rd St at Tennessee St      674          2
# 14            74            Laguna St at Hayes St     5487          2
#
#     user_birth_year user_gender  tire_size
# 0              1959        Male         26
# 1              1965        Male         27
# 2              1993        Male         29
# 3              1979        Male         26
# 4              1994        Male         27
# 5              1979        Male         29
# 6              1981        Male         26
# 7              1991        Male         27
# 8              1982      Female         29
# 9              1994        Male         26
# 10             1983        Male         27
# 11             1990        Male         29
# 12             1998        Male         26
# 13             1987      Female         27
# 14             1997        Male         29

# %%
# Show the min and max values of ride durations (the shortest and longest rides)
# Hint: If 'df' is the name of your dataframe, simply specify the column name
# and then append the .min() or .max() methods.
ride_sharing.min()
# Out:
# duration                              1
# station_A_id                          3
# station_A_name       Berry St at 4th St
# station_B_id                          3
# station_B_name     11th St at Bryant St
# bike_id                              11
# user_type                             1
# user_birth_year                    1901
# user_gender                      Female
# tire_size                            26
# dtype: object

# %%
ride_sharing.max()
# Out:
# duration                                                        1372
# station_A_id                                                      81
# station_A_name                               Steuart St at Market St
# station_B_id                                                     383
# station_B_name     Yerba Buena Center for the Arts (Howard St at ...
# bike_id                                                         6638
# user_type                                                          3
# user_birth_year                                                 2001
# user_gender                                                    Other
# tire_size                                                         29
# dtype: object

# %%
# Create a new dataframe object and populate it with rides that are 60 minutes or less.
# Hint: Use the .query() method for the dataframe that we used in class.
rides_60 = ride_sharing.query('duration <= 60')

# %%
# Now show both the min and max values of the duration column for your new dataset.
rides_60.min()
# Out:
# duration                              1
# station_A_id                          3
# station_A_name       Berry St at 4th St
# station_B_id                          3
# station_B_name     11th St at Bryant St
# bike_id                              11
# user_type                             1
# user_birth_year                    1901
# user_gender                      Female
# tire_size                            26
# dtype: object

# %%
rides_60.max()
# Out:
# duration                                                          60
# station_A_id                                                      81
# station_A_name                               Steuart St at Market St
# station_B_id                                                     383
# station_B_name     Yerba Buena Center for the Arts (Howard St at ...
# bike_id                                                         6638
# user_type                                                          3
# user_birth_year                                                 2001
# user_gender                                                    Other
# tire_size                                                         29
# dtype: object

# %%
# Using the new dataframe, update it so that is ONLY has records where
# the tire_size is 26.
tire_size26 = rides_60.query('tire_size == 26')

# %%
tire_size26.head(15)
# Out:
#     duration  station_A_id                                     station_A_name  \
# 0         12            81                                 Berry St at 4th St
# 3          4            16                            Steuart St at Market St
# 6         16            67  San Francisco Caltrain Station 2  (Townsend St...
# 9          5            30     San Francisco Caltrain (Townsend St at 4th St)
# 12         7             3       Powell St BART Station (Market St at 4th St)
# 15         4             3       Powell St BART Station (Market St at 4th St)
# 18        16            16                            Steuart St at Market St
# 21        11            67  San Francisco Caltrain Station 2  (Townsend St...
# 24        11             3       Powell St BART Station (Market St at 4th St)
# 27         7             3       Powell St BART Station (Market St at 4th St)
# 28         5            15  San Francisco Ferry Building (Harry Bridges Pl...
# 29         6            81                                 Berry St at 4th St
# 33        16            67  San Francisco Caltrain Station 2  (Townsend St...
# 34        11            81                                 Berry St at 4th St
# 35        11             3       Powell St BART Station (Market St at 4th St)
#
#     station_B_id                                 station_B_name  bike_id  \
# 0            323                             Broadway at Kearny     5480
# 3             28                   The Embarcadero at Bryant St     1883
# 6            107                          17th St at Dolores St     1035
# 9             62                    Victoria Manalo Draves Park      333
# 12            27                        Beale St at Harrison St     1863
# 15           321                               5th St at Folsom     1606
# 18            42  San Francisco City Hall (Polk St at Grove St)     5000
# 21           364                       China Basin St at 3rd St     5055
# 24           109                         17th St at Valencia St     4980
# 27            61                            Howard St at 8th St     2459
# 28             6                  The Embarcadero at Sansome St     5193
# 29           116                      Mississippi St at 17th St      903
# 33            76                     McCoppin St at Valencia St     3397
# 34           356                    Valencia St at Clinton Park     5504
# 35            74                          Laguna St at Hayes St      531
#
#     user_type  user_birth_year user_gender  tire_size
# 0           2             1959        Male         26
# 3           1             1979        Male         26
# 6           2             1981        Male         26
# 9           1             1994        Male         26
# 12          3             1998        Male         26
# 15          2             1995        Male         26
# 18          2             2000      Female         26
# 21          3             1986        Male         26
# 24          1             1980        Male         26
# 27          2             1977        Male         26
# 28          3             1990        Male         26
# 29          1             1990        Male         26
# 33          3             1979        Male         26
# 34          2             1994        Male         26
# 35          2             1988        Male         26

# %%
# Finally, produce a count of all records with FEMALE riders
# using the 26-inch wheeled rental bikes for their rentals of
# one hour or less.
f_tiresize26_60 = tire_size26.query('user_gender == "Female"')

# %%
f_tiresize26_60.head(15)
# Out:
#      duration  station_A_id  \
# 18         16            16
# 41         12             3
# 45          1            67
# 52         13            21
# 53         14            21
# 57         11            21
# 75         11            21
# 76         18            22
# 88          6            81
# 89         11             3
# 93          9             3
# 94          9             3
# 95         10             3
# 107         5             3
# 117         8             5
#
#                                         station_A_name  station_B_id  \
# 18                             Steuart St at Market St            42
# 41        Powell St BART Station (Market St at 4th St)             6
# 45   San Francisco Caltrain Station 2  (Townsend St...            64
# 52    Montgomery St BART Station (Market St at 2nd St)            78
# 53    Montgomery St BART Station (Market St at 2nd St)            78
# 57    Montgomery St BART Station (Market St at 2nd St)            61
# 75    Montgomery St BART Station (Market St at 2nd St)            58
# 76                               Howard St at Beale St            72
# 88                                  Berry St at 4th St           130
# 89        Powell St BART Station (Market St at 4th St)            58
# 93        Powell St BART Station (Market St at 4th St)            58
# 94        Powell St BART Station (Market St at 4th St)            58
# 95        Powell St BART Station (Market St at 4th St)            58
# 107       Powell St BART Station (Market St at 4th St)            16
# 117       Powell St BART Station (Market St at 5th St)            47
#
#                                     station_B_name  bike_id  user_type  \
# 18   San Francisco City Hall (Polk St at Grove St)     5000          2
# 41                   The Embarcadero at Sansome St     2899          1
# 45                            5th St at Brannan St     2436          2
# 52                             Folsom St at 9th St     2531          2
# 53                             Folsom St at 9th St     1502          2
# 57                             Howard St at 8th St     2918          2
# 75                            Market St at 10th St      316          2
# 76                             Page St at Scott St     5162          2
# 88                        22nd St Caltrain Station     5224          2
# 89                            Market St at 10th St      192          2
# 93                            Market St at 10th St     1465          1
# 94                            Market St at 10th St      685          1
# 95                            Market St at 10th St     3109          1
# 107                        Steuart St at Market St      593          2
# 117                          4th St at Harrison St     5474          2
#
#      user_birth_year user_gender  tire_size
# 18              2000      Female         26
# 41              1967      Female         26
# 45              1990      Female         26
# 52              1999      Female         26
# 53              1998      Female         26
# 57              1999      Female         26
# 75              1999      Female         26
# 76              1980      Female         26
# 88              1983      Female         26
# 89              2000      Female         26
# 93              1999      Female         26
# 94              1991      Female         26
# 95              2000      Female         26
# 107             2000      Female         26
# 117             1997      Female         26
